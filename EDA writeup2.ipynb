# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# **let us try to do univarient numerical analysis on a column**

# %% [markdown]
# **working on balance column**

# %%
bank_df["balance"]
# Out:
# 0       1787
# 1       4789
# 2       1350
# 3       1476
# 4          0
#         ...
# 4516    -333
# 4517   -3313
# 4518     295
# 4519    1137
# 4520    1136
# Name: balance, Length: 4521, dtype: int64

# %% [markdown]
# **let us fing the following things on balance column**
# - **1) mean**
# - **2) median**
# - **3) count**
# - **4) min**
# - **5) standard deviation**

# %% [markdown]
# **min**
# - finding the minimum value in the balance column

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
bank_df["balance"].min()
# Out:
# -3313

# %% [markdown]
# **max**
# - finding the maximum  value in the balance column

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
bank_df["balance"].max()
# Out:
# 71188

# %% [markdown]
# **count**
# - counting the number of columns in the given column

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
bank_df["balance"].count()
# Out:
# 4521

# %% [markdown]
# **mean**
# - finding the mean value of the entire column obseravtions

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
bank_df["balance"].mean()
# Out:
# 1422.6578190665782

# %% [markdown]
# **median**
# - finding the median value of the column

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
bank_df["balance"].median()
# Out:
# 444.0

# %% [markdown]
# **standard deviation**
# - finding the satndard deviation of the data

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
bank_df["balance"].std()
# Out:
# 3009.638142467341

# %% [markdown]
# **now make the dataframe of above data**

# %% [markdown]
# **method -1**
# - using dictionary

# %%
dict1={}
min_value=bank_df["balance"].min()
max_value=bank_df["balance"].max()
count_value=bank_df["balance"].count()
mean_value=bank_df["balance"].mean()
median_value=bank_df["balance"].median()
std_value=bank_df["balance"].std()
list_1=[min_value,max_value,count_value,mean_value,median_value,std_value]
dict1["balance"]=list_1
pd.DataFrame(dict1,index=["min","max","count","mean","median","std"])
# Out:
#              balance
# min     -3313.000000
# max     71188.000000
# count    4521.000000
# mean     1422.657819
# median    444.000000
# std      3009.638142

# %% [markdown]
# **using list**

# %%
min_value=bank_df["balance"].min()
max_value=bank_df["balance"].max()
count_value=bank_df["balance"].count()
mean_value=bank_df["balance"].mean()
median_value=bank_df["balance"].median()
std_value=bank_df["balance"].std()
list_1=[min_value,max_value,count_value,mean_value,median_value,std_value]
pd.DataFrame(list_1,index=["min","max","count","mean","median","std"])
# Out:
#                    0
# min     -3313.000000
# max     71188.000000
# count    4521.000000
# mean     1422.657819
# median    444.000000
# std      3009.638142

# %% [markdown]
# - **we make analysis for one numerical column**
# - **now we will try to make every numerical column analysis**

# %% [markdown]
# **step-1**
# - **identify which columns are numeric**

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
bank_df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %% [markdown]
# **step-2**
# - try to seperate the numerical and categorical columns

# %%
bank_df.dtypes.keys()
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
a=dict(bank_df.dtypes)
b=[i for i in a if i!='O']
b
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'day',
#  'month',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'y']

# %% [markdown]
# **step-3 make each analysis**

# %%
a=dict(bank_df.dtypes)
x=[]
dict_1={}
for i,j in a.items():
    if j!='O':
       x.append(i)
for i in x:
    min_value=bank_df[i].min()
    max_value=bank_df[i].max()
    count_value=bank_df[i].count()
    mean_value=bank_df[i].mean()
    median_value=bank_df[i].median()
    std_value=bank_df[i].std()
    list_1=[min_value,max_value,count_value,mean_value,median_value,std_value]
    dict_1[i]=list_1
pd.DataFrame(dict_1,index=['min','max','count','mean','median','std'])
# Out:
#                 age       balance          day     duration     campaign  \
# min       19.000000  -3313.000000     1.000000     4.000000     1.000000
# max       87.000000  71188.000000    31.000000  3025.000000    50.000000
# count   4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean      41.170095   1422.657819    15.915284   263.961292     2.793630
# median    39.000000    444.000000    16.000000   185.000000     2.000000
# std       10.576211   3009.638142     8.247667   259.856633     3.109807
#
#               pdays     previous
# min       -1.000000     0.000000
# max      871.000000    25.000000
# count   4521.000000  4521.000000
# mean      39.766645     0.542579
# median    -1.000000     0.000000
# std      100.121124     1.693562

# %% [markdown]
# **describe()**

# %% [markdown]
# we can get the above values directly by using the describe method**

# %%
bank_df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %% [markdown]
# **percentile and quantile**

# %% [markdown]
#  - percentile ranges from 1 to 100
#
# - quantile q1=25P  q2=50p  q3=75p
#
# - np.percentile(<direct number between 1 to 100>,data)
#
# - ex: np.percentile(75,data)
#
# - np.quantile(<decimal number>,data)
#
# - ex: np.quantile(0.75,data)

# %% [markdown]
# **percentile**

# %%
import numpy as np
q1=np.percentile(bank_df['balance'],25)
q2=np.percentile(bank_df['balance'],50)
q3=np.percentile(bank_df['balance'],75)
print(q1,q2,q3)
# Out:
# 69.0 444.0 1480.0

# %% [markdown]
# **quantiles**

# %%
import numpy as np
q1=np.quantile(bank_df['balance'],0.25)
q2=np.quantile(bank_df['balance'],0.50)
q3=np.quantile(bank_df['balance'],0.75)
print(q1,q2,q3)
# Out:
# 69.0 444.0 1480.0

# %%
a=dict(bank_df.dtypes)
x=[]
dict_1={}
for i,j in a.items():
    if j!='O':
       x.append(i)
for i in x:
    min_value=bank_df[i].min()
    max_value=bank_df[i].max()
    count_value=bank_df[i].count()
    mean_value=bank_df[i].mean()
    median_value=bank_df[i].median()
    std_value=bank_df[i].std()
    q1=np.percentile(bank_df[i],25)
    q2=np.percentile(bank_df[i],50)
    q3=np.percentile(bank_df[i],75)
    list_1=[min_value,max_value,count_value,mean_value,median_value,std_value,q1,q2,q3]
    dict_1[i]=list_1
pd.DataFrame(dict_1,index=['min','max','count','mean','median','std','25','50','75'])
# Out:
#                 age       balance          day     duration     campaign  \
# min       19.000000  -3313.000000     1.000000     4.000000     1.000000
# max       87.000000  71188.000000    31.000000  3025.000000    50.000000
# count   4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean      41.170095   1422.657819    15.915284   263.961292     2.793630
# median    39.000000    444.000000    16.000000   185.000000     2.000000
# std       10.576211   3009.638142     8.247667   259.856633     3.109807
# 25        33.000000     69.000000     9.000000   104.000000     1.000000
# 50        39.000000    444.000000    16.000000   185.000000     2.000000
# 75        49.000000   1480.000000    21.000000   329.000000     3.000000
#
#               pdays     previous
# min       -1.000000     0.000000
# max      871.000000    25.000000
# count   4521.000000  4521.000000
# mean      39.766645     0.542579
# median    -1.000000     0.000000
# std      100.121124     1.693562
# ...

# %% [markdown]
# **Empirical rule**

# %% [markdown]
# <img src="https://www.wallstreetmojo.com/wp-content/uploads/2020/06/Empirical-Rule.jpg" jsaction="VQAsE" class="sFlh5c pT0Scc iPVvYb" style="max-width: 698px; height: 260px; margin: 0px; width: 465px;" alt="Empirical Rule - What Is It, Formula, How To Use, Examples" jsname="kn3ccd" aria-hidden="false">

# %% [markdown]
# **let us check the emperical rule is correct or not**

# %% [markdown]
# when data follows a normal distribution
#
# - u-1sigma to u+1sigma : 68%
#
# - u-2sigma to u+2sigma : 95%
#
# - u-3sigma to u+3sigma : 99.7%

# %% [markdown]
# **let us work on balance column**

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
print("**************68% of data*********")
first_min_value=bank_df['balance'].mean()-(1*bank_df['balance'].std())
first_max_value=bank_df['balance'].mean()+(1*bank_df['balance'].std())
con1=bank_df['balance']>first_min_value
con2=bank_df['balance']<first_max_value
print("the first range count of values is ",len(bank_df[con1&con2]))
print("percentage",(len(bank_df[con1&con2])*100/len(bank_df)))
print("**************95% of data*********")
second_min_value=bank_df['balance'].mean()-(2*bank_df['balance'].std())
second_max_value=bank_df['balance'].mean()+(2*bank_df['balance'].std())
con1=bank_df['balance']>second_min_value
con2=bank_df['balance']<second_max_value
print("the second range count of values is ",len(bank_df[con1&con2]))
print("percentage",(len(bank_df[con1&con2])*100/len(bank_df)))
print("**************99.7% of data*********")
third_min_value=bank_df['balance'].mean()-(3*bank_df['balance'].std())
third_max_value=bank_df['balance'].mean()+(3*bank_df['balance'].std())
con1=bank_df['balance']>third_min_value
con2=bank_df['balance']<third_max_value
print("the first range count of values is ",len(bank_df[con1&con2]))
print("percentage",(len(bank_df[con1&con2])*100/len(bank_df)))
# Out:
# **************68% of data*********
# the first range count of values is  4143
# percentage 91.63901791639017
# **************95% of data*********
# the second range count of values is  4355
# percentage 96.32824596328246
# **************99.7% of data*********
# the first range count of values is  4433
# percentage 98.05352798053528

# %% [markdown]
# **compare the mean and median values**

# %% [markdown]
# **let us take a income column**
# - **mean 1422.657819**
# - **median 444.000000**
# - **it looks like mean>median**
# - **data must be skewed**
# - **in order to check whether it is right or left skewed we need a histogram**

# %% [markdown]
# **histogram**

# %% [markdown]
# - A histogram is a widely used graph to show the distribution of quantitative (numerical) data.
#
# - It shows the frequency of values in the data, usually in intervals of values. Frequency is the amount of times that value appeared in the data.
#
# - Each interval is represented with a bar, placed next to the other intervals on a number line.
#
# - The height of the bar represents the frequency of values in that interval.

# %%
import matplotlib.pyplot as plt
plt.hist(bank_df['balance'],bins=20)
# Out:
# (array([2.172e+03, 1.939e+03, 2.590e+02, 8.100e+01, 3.200e+01, 1.500e+01,
#         1.100e+01, 6.000e+00, 4.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([-3313.  ,   412.05,  4137.1 ,  7862.15, 11587.2 , 15312.25,
#         19037.3 , 22762.35, 26487.4 , 30212.45, 33937.5 , 37662.55,
#         41387.6 , 45112.65, 48837.7 , 52562.75, 56287.8 , 60012.85,
#         63737.9 , 67462.95, 71188.  ]),
#  <BarContainer object of 20 artists>)

# %%
len(bank_df[bank_df["balance"].between(1.939e+03,2.590e+02)])
# Out:
# 0

# %% [markdown]
# **boxplot**

# %% [markdown]
# <img src="data:image/png;base64,..." data-deferred="1" class="rg_i Q4LuWd" jsname="Q4LuWd" width="318" height="159" alt="Understanding Boxplots - KDnuggets" data-iml="836.6000000238419" data-atf="true">

# %%
plt.boxplot(bank_df["balance"],vert=False)
plt.show()

# %% [markdown]
# - Removal of outliers
#
# - Impute the outliers with medain value
#
# - because medain is not impact by Outliers
# - Cap the outliers with Q3, which are having more than Q3
#
# - Cap the outliers with Q1, which are having less than Q1

# %% [markdown]
# **remove the outliers**

# %%
q1=np.percentile(bank_df["balance"],25)
q2=np.percentile(bank_df["balance"],50)
q3=np.percentile(bank_df["balance"],75)
iqr=q3-q1
upper_bound=q3+1.5*iqr
lower_bound=q1-1.5*iqr
con1=bank_df["balance"]>upper_bound
con2=bank_df["balance"]<lower_bound
len(bank_df["balance"][con1|con2])
# Out:
# 506

# %%
q1=np.percentile(bank_df["balance"],25)
q2=np.percentile(bank_df["balance"],50)
q3=np.percentile(bank_df["balance"],75)
iqr=q3-q1
upper_bound=q3+1.5*iqr
lower_bound=q1-1.5*iqr
con1=bank_df["balance"]<upper_bound
con2=bank_df["balance"]>lower_bound
non_outliers=bank_df["balance"][con1&con2]
len(non_outliers)
# Out:
# 4015

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
plt.title("outlier data using box-plot")
plt.boxplot(bank_df["balance"],vert=False)

plt.subplot(2,2,2)
plt.title("after removing the outliers")
q1=np.percentile(bank_df["balance"],25)
q2=np.percentile(bank_df["balance"],50)
q3=np.percentile(bank_df["balance"],75)
iqr=q3-q1
upper_bound=q3+1.5*iqr
lower_bound=q1-1.5*iqr
con1=bank_df["balance"]<upper_bound
con2=bank_df["balance"]>lower_bound
non_outliers=bank_df["balance"][con1&con2]
plt.boxplot(non_outliers,vert=False)
plt.subplot(2,2,3)
plt.hist(bank_df["balance"])
plt.subplot(2,2,4)
plt.hist(non_outliers)
plt.show()

# %% [markdown]
# **impute median value**

# %%
l=[]
q1=np.percentile(bank_df["balance"],25)
q2=np.percentile(bank_df["balance"],50)
q3=np.percentile(bank_df["balance"],75)
iqr=q3-q1
upper_bound=q3+1.5*iqr
lower_bound=q1-1.5*iqr
for i in bank_df["balance"]:
    if i>upper_bound or i<lower_bound:
        l.append(q2)
    else:
        l.append(i)
plt.hist(l)
plt.show()

# %%
l=[]
q1=np.percentile(bank_df["balance"],25)
q2=np.percentile(bank_df["balance"],50)
q3=np.percentile(bank_df["balance"],75)
iqr=q3-q1
upper_bound=q3+1.5*iqr
lower_bound=q1-1.5*iqr
for i in bank_df["balance"]:
    if i>upper_bound or i<lower_bound:
        l.append(q2)
    else:
        l.append(i)
plt.boxplot(l,vert=False)
plt.show()

# %% [markdown]
# **np.where()**

# %% [markdown]
# np.where will take 3 argument values
#
# Condition : con=data['Col1']>2
#
# If that condition is True will provide the value:100
#
# If that condition is False will keep the same value: data['Col1']
#
# np.where(,,)

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
q1=np.percentile(bank_df["balance"],25)
q2=np.percentile(bank_df["balance"],50)
q3=np.percentile(bank_df["balance"],75)
iqr=q3-q1
upper_bound=q3+1.5*iqr
lower_bound=q1-1.5*iqr
con1=bank_df["balance"]>upper_bound
con2=bank_df["balance"]<lower_bound
con=con1|con2
q2=bank_df["balance"].median()
bank_df["balance"]=np.where(con,q2,bank_df["balance"])
plt.boxplot(bank_df["balance"],vert=False)

plt.subplot(2,2,2)
plt.hist(bank_df["balance"])
plt.show()

# %% [markdown]
# **Data Transformation**

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
print("**************68% of data*********")
first_min_value=bank_df['balance'].mean()-(1*bank_df['balance'].std())
first_max_value=bank_df['balance'].mean()+(1*bank_df['balance'].std())
con1=bank_df['balance']>first_min_value
con2=bank_df['balance']<first_max_value
print("the first range count of values is ",len(bank_df[con1&con2]))
print("percentage",(len(bank_df[con1&con2])*100/len(bank_df)))
print("**************95% of data*********")
second_min_value=bank_df['balance'].mean()-(2*bank_df['balance'].std())
second_max_value=bank_df['balance'].mean()+(2*bank_df['balance'].std())
con1=bank_df['balance']>second_min_value
con2=bank_df['balance']<second_max_value
print("the second range count of values is ",len(bank_df[con1&con2]))
print("percentage",(len(bank_df[con1&con2])*100/len(bank_df)))
print("**************99.7% of data*********")
third_min_value=bank_df['balance'].mean()-(3*bank_df['balance'].std())
third_max_value=bank_df['balance'].mean()+(3*bank_df['balance'].std())
con1=bank_df['balance']>third_min_value
con2=bank_df['balance']<third_max_value
print("the first range count of values is ",len(bank_df[con1&con2]))
print("percentage",(len(bank_df[con1&con2])*100/len(bank_df)))
# Out:
# **************68% of data*********
# the first range count of values is  4143
# percentage 91.63901791639017
# **************95% of data*********
# the second range count of values is  4355
# percentage 96.32824596328246
# **************99.7% of data*********
# the first range count of values is  4433
# percentage 98.05352798053528

# %% [markdown]
# - **68%------------- 91.63**
# - **95%-------------96.328**
# - **99.7%-----------98.053527**

# %% [markdown]
# - **converted the skewed data into normal distribution is very important matter**
# - **all maths are developed by the normal distribution**

# %% [markdown]
# **methods**
# - log transformation
#
# - Reciprocal transformation
#
# - sqrt transformation
#
# - exponential transformation
#
# - box-cox transformation
#
# - yeo-jhanosn transformation

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
work_data=bank_df["balance"]
work_data
# Out:
# 0       1787
# 1       4789
# 2       1350
# 3       1476
# 4          0
#         ...
# 4516    -333
# 4517   -3313
# 4518     295
# 4519    1137
# 4520    1136
# Name: balance, Length: 4521, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.hist(work_data)
plt.show()

# %% [markdown]
# **Log-Transformation**

# %% [markdown]
# - np.log represents natural logorithm
#
# - natural logorithm means base e
#
# - exponential will multiply with log base e
#
# - Natural logorithms will works postive data
#
# - log transformation will remove the skew
#
# - It will not convert into Normal distribution

# %% [markdown]
# **Reciprocal transformation**

# %% [markdown]
# - it will have the data as 1/data
# - it will be fail if the data contains the value 0
# - 1/0 will leads to infinite
# - so when ever the data contains zero try to not use the reciprocal transformation

# %% [markdown]
# **sqrt transformation**

# %% [markdown]
# - **sqrt transformation  we are doing square root of data and we are ploting the data in the histogram**
# - **it may convert the skewed data into normal data**

# %%
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
work_data=bank_df["age"]
plt.hist(work_data,bins=40,label="normal-data")
plt.legend()
plt.show()

# %%
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
work_data=bank_df["age"]
log_data=np.log(work_data)
plt.hist(log_data,bins=40,label="log-transformation")
plt.legend()
plt.show()

# %%
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
work_data=bank_df["age"]
rp=1/work_data
plt.hist(rp,bins=40,label="reciprocal-transformation")
plt.legend()
plt.show()

# %%
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
work_data=bank_df["age"]
sqrt=work_data**0.5
plt.hist(sqrt,bins=40,label="sqrt-transformation")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,8))
plt.subplot(2,2,1)
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
work_data=bank_df["age"]
plt.hist(work_data,bins=40,label="normal-data")
plt.legend()
plt.subplot(2,2,2)
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
work_data=bank_df["age"]
log_data=np.log(work_data)
plt.hist(log_data,bins=40,label="log-transformation")
plt.legend()

plt.subplot(2,2,3)
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
work_data=bank_df["age"]
rp=1/work_data
plt.hist(rp,bins=40,label="reciprocal-transformation")
plt.legend()
plt.subplot(2,2,4)
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
work_data=bank_df["age"]
sqrt=work_data**0.5
plt.hist(sqrt,bins=40,label="sqrt-transformation")
plt.legend()
plt.show()

# %% [markdown]
# - **power transformer**
# - **Box-Cox Transformation**: Can be used be used on positive values only
# - **yeo-johnson Transformation**: Can be used on both positive and negative values

# %% [markdown]
# **working with yeo-johnson method**

# %%
from sklearn.preprocessing import PowerTransformer
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
work_data=bank_df["balance"]
data=PowerTransformer(method='yeo-johnson')
x=data.fit_transform(bank_df[["balance"]])
plt.hist(x)
plt.show()

# %%
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
work_data=bank_df["balance"]
plt.title("normal data")
plt.hist(work_data)

plt.subplot(1,2,2)
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
work_data=bank_df["balance"]
data=PowerTransformer(method='yeo-johnson')
x=data.fit_transform(bank_df[["balance"]])
plt.title("data after using yeo-johnson method")
plt.hist(x)
plt.show()

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
work_data=bank_df["age"]
plt.hist(work_data,bins=40)
plt.show()

# %% [markdown]
# **working with the box-cox**
# - we know that the box-cox only works for the postive values only
# - so we change our column to age because  age will never be negative
# - and we used box-cox and we acheived the normal-distribution

# %%
from sklearn.preprocessing import PowerTransformer
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
work_data=bank_df["age"]
data=PowerTransformer(method='box-cox')
x=data.fit_transform(bank_df[["age"]])
plt.hist(x,bins=40)
plt.show()

# %%
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
work_data=bank_df["age"]
plt.title("normal_data")
plt.hist(work_data,bins=40)

plt.subplot(1,2,2)
from sklearn.preprocessing import PowerTransformer
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
work_data=bank_df["age"]
data=PowerTransformer(method='box-cox')
x=data.fit_transform(bank_df[["age"]])
plt.title("using the box-cox")
plt.hist(x,bins=40)
plt.show()

# %% [markdown]
# **bivariate analysis and multivariate analysis**

# %%
#read the data

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_df["marital"].value_counts()
# Out:
# marital
# married     2797
# single      1196
# divorced     528
# Name: count, dtype: int64

# %%
bank_df["loan"].value_counts()
# Out:
# loan
# no     3830
# yes     691
# Name: count, dtype: int64

# %% [markdown]
# **let us find how many married people got loan and how many not got a loan**

# %%
a=bank_df["marital"]=="married"
b=bank_df["loan"]=="yes"
len(bank_df[a&b])
# Out:
# 453

# %%
loan_approved=[]
loan_rejected=[]
for i in bank_df["marital"].unique():
    con1=bank_df["marital"]==i
    con2=bank_df["loan"]=="yes"
    con3=bank_df["loan"]=="no"
    loan_approved.append(len(bank_df[con1&con2]))
    loan_rejected.append(len(bank_df[con1&con3]))
pd.DataFrame(zip(bank_df["marital"].unique(),loan_approved,loan_rejected),columns=["persons_type","loan_approved","loan_rejected"])
# Out:
#   persons_type  loan_approved  loan_rejected
# 0      married            453           2344
# 1       single            148           1048
# 2     divorced             90            438

# %% [markdown]
# **pd.crosstab**

# %%
col1=bank_df["marital"]
col2=bank_df["loan"]
k=pd.crosstab(col1,col2)
k
# Out:
# loan        no  yes
# marital
# divorced   438   90
# married   2344  453
# single    1048  148

# %%
k.plot(kind='bar')
# Out:
# <Axes: xlabel='marital'>

# %% [markdown]
# **let us do more analysis by taking 3 columns**

# %%
col1=bank_df["marital"]
col2=bank_df["loan"]
col3=bank_df["education"]
col4=[col3,col2]
l1=pd.crosstab(col1,col4)
# Out:
# education primary     secondary      tertiary      unknown
# loan           no yes        no  yes       no  yes      no yes
# marital
# divorced       70   9       219   51      125   30      24   0
# married       451  75      1154  273      627  100     112   5
# single         63  10       517   92      424   44      44   2

# %%
col1=bank_df["marital"]
col2=bank_df["loan"]
col3=bank_df["education"]
col4=[col3,col2]
l1=pd.crosstab(col1,col4)
l1.plot(kind="bar")
# Out:
# <Axes: xlabel='marital'>

# %% [markdown]
# **scatter plots**

# %%
x=[1,2,3,4,5]
y=[11,12,13,14,15]

#(1,11),(2,12),(3,13),(4,14),(5,15)
plt.scatter(x,y)

# %%
x=[i for i in range(-10,11)]
y=[i*i for i in x]
x
plt.scatter(x,y)
plt.plot(x,y)

# %% [markdown]
# -Scatter plots for only numerical analysis
#
# -Scatter plots provides an idea , both variables are related or not related
#
# - Postivie relation
#
#   - Increase in the curve
# - Negative relation
#
#   - Decrease in the curve
# - No realtion
#
#   - Neither increase nor Decrease

# %%
a=bank_df["age"]
b=bank_df["balance"]
plt.scatter(a,b)

# %% [markdown]
# **correlation**

# %% [markdown]
# Denoted with r
#
# r range from -1 to 1
#
# postive relation range = (0,1]
#
# negative relation range = [-1,0)

# %%
bank_df.corr(numeric_only=True)
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.083820 -0.017853 -0.002367 -0.005148 -0.008894 -0.003511
# balance   0.083820  1.000000 -0.008677 -0.015950 -0.009976  0.009437  0.026196
# day      -0.017853 -0.008677  1.000000 -0.024629  0.160706 -0.094352 -0.059114
# duration -0.002367 -0.015950 -0.024629  1.000000 -0.068382  0.010380  0.018080
# campaign -0.005148 -0.009976  0.160706 -0.068382  1.000000 -0.093137 -0.067833
# pdays    -0.008894  0.009437 -0.094352  0.010380 -0.093137  1.000000  0.577562
# previous -0.003511  0.026196 -0.059114  0.018080 -0.067833  0.577562  1.000000

# %%
plt.scatter(bank_df["age"],bank_df["campaign"])

# %% [markdown]
# **heatmap**

# %%
import seaborn as sns
a=bank_df.corr(numeric_only=True)
sns.heatmap(a,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **converting the categorical columns into numeric columns**

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# - In Machine learning algorithms will develop models by using maths
#
# - Maths allows only numbers
#
# - So it is very important , you need to pass numerical data only
#
# - So we need to convert categorical data to numerical data
#
# - For that we have encoding methods
#
# - Encoding
#
# - Lable encoder
#
# - map method
#
# - np.where
#
# - LableEncoder package from sklearn
#
# - One hot encoder
#
# - pd.get_dummies()

# %% [markdown]
# **map-method**

# %%
bank_df["loan"].unique()
dict1={"yes":1,"no":2}
bank_df["loan"].map(dict1)
# Out:
# 0       2
# 1       1
# 2       2
# 3       1
# 4       2
#        ..
# 4516    2
# 4517    1
# 4518    2
# 4519    2
# 4520    1
# Name: loan, Length: 4521, dtype: int64

# %% [markdown]
# **create a new_column**

# %%
bank_df["loan"].unique()
dict1={"yes":1,"no":2}
bank_df["new_loan"]=bank_df["loan"].map(dict1)
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# **overwrite on same column**

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
bank_df["loan"]=bank_df["loan"].map(dict1)
bank_df
# Out:
#       age            job  marital  education default  balance housing  loan  \
# 0      30     unemployed  married    primary      no     1787      no     2
# 1      33       services  married  secondary      no     4789     yes     1
# 2      35     management   single   tertiary      no     1350     yes     2
# 3      30     management  married   tertiary      no     1476     yes     1
# 4      59    blue-collar  married  secondary      no        0     yes     2
# ...   ...            ...      ...        ...     ...      ...     ...   ...
# 4516   33       services  married  secondary      no     -333     yes     2
# 4517   57  self-employed  married   tertiary     yes    -3313     yes     1
# 4518   57     technician  married  secondary      no      295      no     2
# 4519   28    blue-collar  married  secondary      no     1137      no     2
# 4520   44   entrepreneur   single   tertiary      no     1136     yes     1
#
# ...

# %% [markdown]
# **method-2**

# %% [markdown]
# **np.where**

# %% [markdown]
# - np.where() is applicable for binary conditions
#
# - which means it is applicable only for two lables
#
# - np.where(condition,Truevalue,False_value)
#
# - For example case_status has two lables
#
# - condition: =='Certified'
#
# - True value: Replace all certified values with 0
#
# - False value: Replace all denied values with 1

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
a=bank_df["loan"]=="yes"
bank_df["loan"]=np.where(a,1,2)
bank_df
# Out:
#       age            job  marital  education default  balance housing  loan  \
# 0      30     unemployed  married    primary      no     1787      no     2
# 1      33       services  married  secondary      no     4789     yes     1
# 2      35     management   single   tertiary      no     1350     yes     2
# 3      30     management  married   tertiary      no     1476     yes     1
# 4      59    blue-collar  married  secondary      no        0     yes     2
# ...   ...            ...      ...        ...     ...      ...     ...   ...
# 4516   33       services  married  secondary      no     -333     yes     2
# 4517   57  self-employed  married   tertiary     yes    -3313     yes     1
# 4518   57     technician  married  secondary      no      295      no     2
# 4519   28    blue-collar  married  secondary      no     1137      no     2
# 4520   44   entrepreneur   single   tertiary      no     1136     yes     1
#
# ...

# %% [markdown]
# **LabelEncoder**

# %% [markdown]
# - LableEncoder is a method from sklearn
#
# - Under sklearn we have sub modules
#
# - One of the submodule: preprocessing
#
# - Any sklearn packages we have only 3 steps
#
# - Step-1: Read the package
#
# - Step-2: Save the package
#
# - Step-3: Apply fit transfotm

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
bank_df["loan"]=le.fit_transform(bank_df["loan"])
bank_df["education"]=le.fit_transform(bank_df["education"])
bank_df
# Out:
#       age            job  marital  education default  balance housing  loan  \
# 0      30     unemployed  married          0      no     1787      no     1
# 1      33       services  married          1      no     4789     yes     0
# 2      35     management   single          2      no     1350     yes     1
# 3      30     management  married          2      no     1476     yes     0
# 4      59    blue-collar  married          1      no        0     yes     1
# ...   ...            ...      ...        ...     ...      ...     ...   ...
# 4516   33       services  married          1      no     -333     yes     1
# 4517   57  self-employed  married          2     yes    -3313     yes     0
# 4518   57     technician  married          1      no      295      no     1
# 4519   28    blue-collar  married          1      no     1137      no     1
# 4520   44   entrepreneur   single          2      no     1136     yes     0
#
# ...

# %% [markdown]
# **one-hot encoder**

# %% [markdown]
# - one hot encoder means at a time only one will be ON(1/True), others are OFF(0/False)
#
# - Supposer housing  has two unique lables
#
# - Yes and No
#
# - In one hot encoder it will create two new columns
#
# - like below
#
# |housing|yes|no|
# |-----------|---------|------|
# |yes|1|0|
# |no|0|1|
#
#
# **Advantage**
#
# - One hot encoder new columns are orthogonal each other
#
# - Orthogonality means 90 degress phase shift
#
# - 90 degress phase shift means perpendicular each other
#
# - Perpendicular means independent each other
#
# - Independent means no relation
#
# - It is very important property that is to avoid relation between varaibes
#
# **Draw back**:
#
# - Assume that you have 100 unique lables for a column
#
# - So it will create 100 new columns
#
# - To process 100 columns we require more memory,more time,more hardaware
#
# - This is called **Curse of Dimensionality**

# %% [markdown]
# **pd.get_dummies()**

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
pd.get_dummies(bank_df,columns=["housing"],dtype="int")
# Out:
#       age            job  marital  education default  balance  ... pdays previous  poutcome   y  housing_no  housing_yes
# 0      30     unemployed  married    primary      no     1787  ...    -1        0   unknown  no           1            0
# 1      33       services  married  secondary      no     4789  ...   339        4   failure  no           0            1
# 2      35     management   single   tertiary      no     1350  ...   330        1   failure  no           0            1
# 3      30     management  married   tertiary      no     1476  ...    -1        0   unknown  no           0            1
# 4      59    blue-collar  married  secondary      no        0  ...    -1        0   unknown  no           0            1
# ...   ...            ...      ...        ...     ...      ...  ...   ...      ...       ...  ..         ...          ...
# 4516   33       services  married  secondary      no     -333  ...    -1        0   unknown  no           0            1
# ...

# %% [markdown]
# **Normalization and standardization**

# %% [markdown]
# - In every dataset we have different columns has different units
#
# - In every dataset we have different columns has values varies from -inf to inf
#
# - It is very important standardize the data, make sure all the column values under same range
#
# - To achieve this we have two methods
#
#      - Normalization
#
#      - standardization

# %% [markdown]
# **Normalization**:
#
#    - min max scalar
#
#
# <img src="data:image/png;base64,..." data-deferred="1" class="rg_i Q4LuWd" jsname="Q4LuWd" width="397" height="128" alt="Data normalization formula. | Download Scientific Diagram" data-iml="1399.800000011921" data-atf="true">

# %% [markdown]
# **Standardization**
#
#   - Z-score
#
# <img src="data:image/png;base64,..." data-deferred="1" class="rg_i Q4LuWd" jsname="Q4LuWd" width="460" height="110" alt="How to Normalize Data Excel – Normalization in Excel - Earn &amp; Excel" data-iml="1400.3999999761581" data-atf="true">

# %%
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)

# %% [markdown]
# **normalization- caliculation**
# - step-1: calcaulate min value of p_Wage= min_wage
# -  step-2: calculate max value of p_wage = max_wage
# -  step-3: Dr= max_wage-min_wage
# - step-4: Nr= p_wage-min_wage
# - step-5: Nr/Dr

# %%
min_value=bank_df["balance"].min()
max_value=bank_df["balance"].max()
nr=bank_df["balance"]-min_value
dr=max_value-min_value
nr/dr
# Out:
# 0       0.068455
# 1       0.108750
# 2       0.062590
# 3       0.064281
# 4       0.044469
#           ...
# 4516    0.039999
# 4517    0.000000
# 4518    0.048429
# 4519    0.059731
# 4520    0.059717
# Name: balance, Length: 4521, dtype: float64

# %% [markdown]
# **save the value to a new column**

# %%
min_value=bank_df["balance"].min()
max_value=bank_df["balance"].max()
nr=bank_df["balance"]-min_value
dr=max_value-min_value
bank_df["balance_updated"]=nr/dr
bank_df
# Out:
#       age            job  marital  education default  balance  ... campaign pdays previous  poutcome   y  balance_updated
# 0      30     unemployed  married    primary      no     1787  ...        1    -1        0   unknown  no         0.068455
# 1      33       services  married  secondary      no     4789  ...        1   339        4   failure  no         0.108750
# 2      35     management   single   tertiary      no     1350  ...        1   330        1   failure  no         0.062590
# 3      30     management  married   tertiary      no     1476  ...        4    -1        0   unknown  no         0.064281
# 4      59    blue-collar  married  secondary      no        0  ...        1    -1        0   unknown  no         0.044469
# ...   ...            ...      ...        ...     ...      ...  ...      ...   ...      ...       ...  ..              ...
# 4516   33       services  married  secondary      no     -333  ...        5    -1        0   unknown  no         0.039999
# ...

# %%
bank_df[["balance","balance_updated"]]
# Out:
#       balance  balance_updated
# 0        1787         0.068455
# 1        4789         0.108750
# 2        1350         0.062590
# 3        1476         0.064281
# 4           0         0.044469
# ...       ...              ...
# 4516     -333         0.039999
# 4517    -3313         0.000000
# 4518      295         0.048429
# 4519     1137         0.059731
# 4520     1136         0.059717
#
# [4521 rows x 2 columns]

# %% [markdown]
# **let us check min and max values**

# %%
bank_df["balance_updated"].min()
# Out:
# 0.0

# %%
bank_df["balance_updated"].max()
# Out:
# 1.0

# %% [markdown]
# **so the range from 0 to 1**

# %% [markdown]
# **let us locate the postion of max and min**

# %%
max_value=bank_df["balance"].idxmax()
min_value=bank_df["balance"].idxmin()
max_value,min_value
# Out:
# (3700, 4517)

# %%
bank_df[["balance","balance_updated"]].iloc[[max_value,min_value]]
# Out:
#       balance  balance_updated
# 3700    71188              1.0
# 4517    -3313              0.0

# %% [markdown]
# - MinMaxScalar
#
# - MinMaxScalar is a method from sklearn preprocessing
#
# - Read the packages
#
# - Save the package
#
# - Apply fit transform

# %%
from sklearn.preprocessing import MinMaxScaler
MS=MinMaxScaler()
bank_df["updated_vaues"]=MS.fit_transform(bank_df[["balance"]])
bank_df
# Out:
#       age            job  marital  education default  ...  previous poutcome   y balance_updated  updated_vaues
# 0      30     unemployed  married    primary      no  ...         0  unknown  no        0.068455       0.068455
# 1      33       services  married  secondary      no  ...         4  failure  no        0.108750       0.108750
# 2      35     management   single   tertiary      no  ...         1  failure  no        0.062590       0.062590
# 3      30     management  married   tertiary      no  ...         0  unknown  no        0.064281       0.064281
# 4      59    blue-collar  married  secondary      no  ...         0  unknown  no        0.044469       0.044469
# ...   ...            ...      ...        ...     ...  ...       ...      ...  ..             ...            ...
# 4516   33       services  married  secondary      no  ...         0  unknown  no        0.039999       0.039999
# ...

# %% [markdown]
# **Z-score**

# %%
# step-1: calculate mean
# step-2: calculate std
# step-3: Nr= x-mean
# step-4: Nr/Std

# %%
import pandas as pd
file_path="E:\\DOWNLOADS\\bank.csv"
bank_df=pd.read_csv(file_path)
mean=bank_df["balance"].mean()
std=bank_df["balance"].std()
nr=bank_df["balance"]-mean
dr=std
bank_df["balance_with _z"]=nr/dr
bank_df
# Out:
#       age            job  marital  education default  balance  ... campaign pdays previous  poutcome   y  balance_with _z
# 0      30     unemployed  married    primary      no     1787  ...        1    -1        0   unknown  no         0.121058
# 1      33       services  married  secondary      no     4789  ...        1   339        4   failure  no         1.118521
# 2      35     management   single   tertiary      no     1350  ...        1   330        1   failure  no        -0.024142
# 3      30     management  married   tertiary      no     1476  ...        4    -1        0   unknown  no         0.017724
# 4      59    blue-collar  married  secondary      no        0  ...        1    -1        0   unknown  no        -0.472701
# ...   ...            ...      ...        ...     ...      ...  ...      ...   ...      ...       ...  ..              ...
# 4516   33       services  married  secondary      no     -333  ...        5    -1        0   unknown  no        -0.583345
# ...

# %%
bank_df[["balance","balance_with _z"]]
# Out:
#       balance  balance_with _z
# 0        1787         0.121058
# 1        4789         1.118521
# 2        1350        -0.024142
# 3        1476         0.017724
# 4           0        -0.472701
# ...       ...              ...
# 4516     -333        -0.583345
# 4517    -3313        -1.573497
# 4518      295        -0.374682
# 4519     1137        -0.094914
# 4520     1136        -0.095247
#
# [4521 rows x 2 columns]

# %%
bank_df["balance_with _z"].min()
# Out:
# -1.5734974089556906

# %%
bank_df["balance_with _z"].max()
# Out:
# 23.18064128591183

# %%
import matplotlib.pyplot as plt
plt.subplot(1,2,1)
plt.boxplot(bank_df["balance"])
plt.subplot(1,2,2)
plt.boxplot(bank_df["balance_with _z"])
plt.show()

# %% [markdown]
# **using Standardscaler**

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
ss.fit_transform(bank_df[["balance"]])
# Out:
# array([[ 0.12107186],
#        [ 1.1186443 ],
#        [-0.02414438],
#        ...,
#        [-0.37472364],
#        [-0.09492484],
#        [-0.09525714]])

# %% [markdown]
# **save to new-column**

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
bank_df["new _one"]=ss.fit_transform(bank_df[["balance"]])
bank_df
# Out:
#       age            job  marital  education default  balance  ... pdays previous poutcome   y balance_with _z  new _one
# 0      30     unemployed  married    primary      no     1787  ...    -1        0  unknown  no        0.121058  0.121072
# 1      33       services  married  secondary      no     4789  ...   339        4  failure  no        1.118521  1.118644
# 2      35     management   single   tertiary      no     1350  ...   330        1  failure  no       -0.024142 -0.024144
# 3      30     management  married   tertiary      no     1476  ...    -1        0  unknown  no        0.017724  0.017726
# 4      59    blue-collar  married  secondary      no        0  ...    -1        0  unknown  no       -0.472701 -0.472753
# ...   ...            ...      ...        ...     ...      ...  ...   ...      ...      ...  ..             ...       ...
# 4516   33       services  married  secondary      no     -333  ...    -1        0  unknown  no       -0.583345 -0.583410
# ...

# %% [markdown]
# **working with the null values**

# %%
import numpy as np
import pandas as pd
dict1={"name":["venkatesh","Nani","preetham",np.nan],
      "age":[20,21,np.nan,23],
      "city":[np.nan,"hyd","goa","tamilnadu"]}
df=pd.DataFrame(dict1)
df
# Out:
#         name   age       city
# 0  venkatesh  20.0        NaN
# 1       Nani  21.0        hyd
# 2   preetham   NaN        goa
# 3        NaN  23.0  tamilnadu

# %% [markdown]
# **here  Nan means empty value**

# %% [markdown]
# **method-1**

# %% [markdown]
# **fill with random value**

# %%
df.fillna(40,inplace=True)
df
# Out:
#         name   age       city
# 0  venkatesh  20.0         40
# 1       Nani  21.0        hyd
# 2   preetham  40.0        goa
# 3         40  23.0  tamilnadu

# %% [markdown]
# - **in this case every value NaN value is replacing with the  random number 40**
# - **so it is a bad way that when we see the column name and city values are 40 which are meaningless**
# - **40 is a number we passed in three columns so every column the type of 40 is different**

# %%
df.dtypes
# Out:
# name     object
# age     float64
# city     object
# dtype: object

# %% [markdown]
# **method-2**

# %% [markdown]
# **fill the values according the column-wise**

# %%
# every time we need to read the data becaues we are using the inplace=True
dict1={"name":["venkatesh","Nani","preetham",np.nan],
      "age":[20,21,np.nan,23],
      "city":[np.nan,"hyd","goa","tamilnadu"]}
df=pd.DataFrame(dict1)
df["name"].fillna("chakri",inplace=True)
df["age"].fillna(32,inplace=True)
df["city"].fillna("Miryalaguda",inplace=True)   
df
# Out:
#         name   age         city
# 0  venkatesh  20.0  Miryalaguda
# 1       Nani  21.0          hyd
# 2   preetham  32.0          goa
# 3     chakri  23.0    tamilnadu

# %% [markdown]
# **method-3**

# %% [markdown]
# - **pad**
# - **ffill**
# - **bfill**
# - **backfill**

# %% [markdown]
# **pad**

# %%
dict1={"name":["venkatesh","Nani","preetham",np.nan],
      "age":[20,21,np.nan,23],
      "city":[np.nan,"hyd","goa","tamilnadu"]}
df=pd.DataFrame(dict1)
df.fillna(method='pad')
# Out:
# C:\Users\Venkatesh\AppData\Local\Temp\ipykernel_8384\3458105288.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='pad')
#         name   age       city
# 0  venkatesh  20.0        NaN
# 1       Nani  21.0        hyd
# 2   preetham  21.0        goa
# 3   preetham  23.0  tamilnadu

# %% [markdown]
# - **it is filling upper value of nan**
# - **for the city the first value is NaN no upper value is present upside of Nan so it is like Nan only**

# %%
dict1={"name":["venkatesh","Nani","preetham",np.nan],
      "age":[20,21,np.nan,23],
      "city":[np.nan,"hyd","goa","tamilnadu"]}
df=pd.DataFrame(dict1)
df.fillna(method='ffill')
# Out:
# C:\Users\Venkatesh\AppData\Local\Temp\ipykernel_8384\1725670102.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#         name   age       city
# 0  venkatesh  20.0        NaN
# 1       Nani  21.0        hyd
# 2   preetham  21.0        goa
# 3   preetham  23.0  tamilnadu

# %% [markdown]
# - **it is filling upper value of nan**
# - **for the city the first value is NaN no upper value is present upside of Nan so it is like Nan only**
# - **ffill and pad both work like same**

# %%
dict1={"name":["venkatesh","Nani","preetham",np.nan],
      "age":[20,21,np.nan,23],
      "city":[np.nan,"hyd","goa","tamilnadu"]}
df=pd.DataFrame(dict1)
df.fillna(method='bfill')
# Out:
# C:\Users\Venkatesh\AppData\Local\Temp\ipykernel_8384\2216112663.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#         name   age       city
# 0  venkatesh  20.0        hyd
# 1       Nani  21.0        hyd
# 2   preetham  23.0        goa
# 3        NaN  23.0  tamilnadu

# %% [markdown]
# - **it is filling lower value of NaN**
# - **for the name  the last  value is NaN no lower  value is present downside  of Nan so it is like Nan only**

# %%
dict1={"name":["venkatesh","Nani","preetham",np.nan],
      "age":[20,21,np.nan,23],
      "city":[np.nan,"hyd","goa","tamilnadu"]}
df=pd.DataFrame(dict1)
df.fillna(method='backfill')
# Out:
# C:\Users\Venkatesh\AppData\Local\Temp\ipykernel_8384\2163603302.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='backfill')
#         name   age       city
# 0  venkatesh  20.0        hyd
# 1       Nani  21.0        hyd
# 2   preetham  23.0        goa
# 3        NaN  23.0  tamilnadu

# %% [markdown]
# - **it is filling lower value of NaN**
# - **for the name the last value is NaN no lower value is present downside of Nan so it is like Nan only**
# - **it looks like backfill and bfill works like same**

# %% [markdown]
# **let us try with axis=1**

# %%
dict1={"name":["venkatesh","Nani","preetham",np.nan],
      "age":[20,21,np.nan,23,],
      "city":[np.nan,"hyd","goa","tamilnadu"]}
df=pd.DataFrame(dict1)
df.fillna(method='backfill',axis=1)
# Out:
# C:\Users\Venkatesh\AppData\Local\Temp\ipykernel_8384\166574945.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='backfill',axis=1)
#         name   age       city
# 0  venkatesh  20.0        NaN
# 1       Nani  21.0        hyd
# 2   preetham   goa        goa
# 3       23.0  23.0  tamilnadu

# %% [markdown]
# - **when we try to use axis=1 the datafreme will be rotated**
# - **so it will be print beside the column value based on the method**
# - **if we use backfill and bfill the right column value is filled in the null value**
# - **if we use pad  and ffill the left column value is filled in the null value**

# %% [markdown]
# **when we  want to  fill the missing value with respective to two columns we use KNN imputer**

# %% [markdown]
# **method-4**

# %% [markdown]
# - **mean**
# - **median**
# - **mode**

# %%
dict1={"name":["venkatesh","Nani","preetham",np.nan,"shashi","naresh","deeksha"],
      "age":[20,21,np.nan,23,45,32,31],
      "city":[np.nan,"hyd","goa","tamilnadu","hyd","ibp","wrangal"]}
data=pd.DataFrame(dict1)
data
# Out:
#         name   age       city
# 0  venkatesh  20.0        NaN
# 1       Nani  21.0        hyd
# 2   preetham   NaN        goa
# 3        NaN  23.0  tamilnadu
# 4     shashi  45.0        hyd
# 5     naresh  32.0        ibp
# 6    deeksha  31.0    wrangal

# %% [markdown]
# **mean**

# %% [markdown]
# **for numerical columns we mostly used mean and median**

# %%
dict1={"name":["venkatesh","Nani","preetham",np.nan,"shashi","naresh","deeksha"],
      "age":[20,21,np.nan,23,45,32,31],
      "city":[np.nan,"hyd","goa","tamilnadu","hyd","ibp","wrangal"]}
data=pd.DataFrame(dict1)
mean_value=data["age"].mean()
data["age"].fillna(mean_value,inplace=True)
data
# Out:
#         name        age       city
# 0  venkatesh  20.000000        NaN
# 1       Nani  21.000000        hyd
# 2   preetham  28.666667        goa
# 3        NaN  23.000000  tamilnadu
# 4     shashi  45.000000        hyd
# 5     naresh  32.000000        ibp
# 6    deeksha  31.000000    wrangal

# %% [markdown]
# **median**

# %%
dict1={"name":["venkatesh","Nani","preetham",np.nan,"shashi","naresh","deeksha"],
      "age":[20,21,np.nan,23,45,32,31],
      "city":[np.nan,"hyd","goa","tamilnadu","hyd","ibp","wrangal"]}
data=pd.DataFrame(dict1)
mean_value=data["age"].median()
data["age"].fillna(mean_value,inplace=True)
data
# Out:
#         name   age       city
# 0  venkatesh  20.0        NaN
# 1       Nani  21.0        hyd
# 2   preetham  27.0        goa
# 3        NaN  23.0  tamilnadu
# 4     shashi  45.0        hyd
# 5     naresh  32.0        ibp
# 6    deeksha  31.0    wrangal

# %%
dict1={"name":["venkatesh","Nani","preetham",np.nan,"shashi","naresh","deeksha"],
      "age":[20,21,np.nan,23,45,32,31],
      "city":[np.nan,"hyd","goa","tamilnadu","hyd","ibp","wrangal"]}
data=pd.DataFrame(dict1)
mean_value=data["city"].mode()
data["city"].fillna(mean_value,inplace=True)
data
# Out:
#         name   age       city
# 0  venkatesh  20.0        hyd
# 1       Nani  21.0        hyd
# 2   preetham   NaN        goa
# 3        NaN  23.0  tamilnadu
# 4     shashi  45.0        hyd
# 5     naresh  32.0        ibp
# 6    deeksha  31.0    wrangal
